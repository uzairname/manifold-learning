# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets.clock import ClockConfig
from vis import load_model, visualize_latent, visualize_predictions, visualize_reconstruction
from train_utils.train import get_dataloaders

data_config = ClockConfig()

IMG_SIZE=128
BATCH_SIZE=64

dataloader, val_dataloader, _, _ = get_dataloaders(
  data_config,
  data_size=2**14,
  img_size=IMG_SIZE,
  batch_size=BATCH_SIZE,
)

# LATENT_DIM=1
# type_ = "encoder"
# model = load_model(
#   img_size=IMG_SIZE,
#   latent_dim=LATENT_DIM,
#   name="ConvMLPEncoder",
#   postfix="d18",
# )

LATENT_DIM=2
type_ = "decoder"
model = load_model(
  img_size=IMG_SIZE,
  latent_dim=LATENT_DIM,
  name="ResNetDecoder",
  postfix="d17",
  checkpoint=0
)

# %% [markdown]
# # Encoders

# %%
visualize_predictions(type_, model, dataloader, latent_dim=LATENT_DIM)

# %% [markdown]
# # Decoders

# %%
visualize_reconstruction(type_, model, dataloader)

# %% [markdown]
# # Autoencoders

# %%
visualize_latent(type_, model, latent_dim=LATENT_DIM, dataloader=dataloader)
